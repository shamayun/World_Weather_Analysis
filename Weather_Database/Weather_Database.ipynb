# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the dependencies.
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Import the random module.
import random

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
print(coordinates[0:3])
# Out:
# [(-49.7728476615747, -80.8884310236205), (-38.29105225992014, -132.83048223679873), (63.29763439513388, -69.32442885774164)]

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# coihaique cl
# rikitea pf
# iqaluit ca
# kodiak us
# mount gambier au
# la baule-escoublac fr
# hermanus za
# albany au
# kemin kg
# avarua ck
# sawtell au
# port alfred za
# kahului us
# saldanha za
# general roca ar
# ponta do sol cv
# cidreira br
# batagay-alyta ru
# avarua ck
# albany au
# vaitupu wf
# albany au
# hobart au
# tuatapere nz
# ulaanbaatar mn
# punta arenas cl
# puerto ayora ec
# mount gambier au
# punta arenas cl
# houma us
# sao filipe cv
# ushuaia ar
# uwayl sd
# albany au
# kahului us
# illoqqortoormiut gl
# bluff nz
# yellowknife ca
# san patricio mx
# buala sb
# hami cn
# rikitea pf
# longyearbyen sj
# dubbo au
# mataura pf
# rikitea pf
# busselton au
# hithadhoo mv
# belushya guba ru
# santa luzia br
# taolanaro mg
# saskylakh ru
# hobart au
# fairborn us
# severo-kurilsk ru
# faanui pf
# egvekinot ru
# kudahuvadhoo mv
# hithadhoo mv
# jamestown sh
# erzin ru
# torbay ca
# punta arenas cl
# busselton au
# stoyba ru
# grand gaube mu
# shetpe kz
# busselton au
# muros es
# ushuaia ar
# dikson ru
# melfi td
# talnakh ru
# butaritari ki
# rikitea pf
# manggar id
# provideniya ru
# yanji cn
# jamestown sh
# georgetown sh
# san rafael del sur ni
# khatanga ru
# hobart au
# sitka us
# goderich sl
# fortuna us
# atuona pf
# severo-kurilsk ru
# busselton au
# vardo no
# punta arenas cl
# marawi sd
# codrington ag
# san rafael del sur ni
# dossor kz
# butaritari ki
# karratha au
# albany au
# caravelas br
# camana pe
# bethel us
# tamandare br
# yertsevo ru
# coolum beach au
# kismayo so
# dawlatabad af
# port keats au
# taolanaro mg
# bayan kw
# busselton au
# katsuura jp
# taolanaro mg
# leh in
# albany au
# albany au
# khatanga ru
# omboue ga
# roma au
# albany au
# dikson ru
# san patricio mx
# birjand ir
# jamestown sh
# albany au
# mataura pf
# norman wells ca
# grand gaube mu
# sitka us
# tsihombe mg
# ushuaia ar
# norman wells ca
# qaanaaq gl
# dawei mm
# rikitea pf
# lebu cl
# east london za
# tasiilaq gl
# ushuaia ar
# promyshlennyy ru
# busselton au
# kachiry kz
# kenai us
# port blair in
# rikitea pf
# vardo no
# bluff nz
# cape town za
# almaznyy ru
# severnyy ru
# evensk ru
# yellowknife ca
# bengkulu id
# airai pw
# belushya guba ru
# airai pw
# grand river south east mu
# georgetown sh
# butaritari ki
# la romana do
# paamiut gl
# port elizabeth za
# castro cl
# busselton au
# nemuro jp
# the valley ai
# vaini to
# mataura pf
# bara sd
# punta arenas cl
# phangnga th
# lakatoro vu
# punta arenas cl
# hermanus za
# cape town za
# mataura pf
# chuy uy
# mahebourg mu
# chernogorsk ru
# kodiak us
# ribeira grande pt
# tiksi ru
# xingyi cn
# gazli uz
# ushuaia ar
# saint-philippe re
# bluff nz
# lagoa pt
# yulara au
# norman wells ca
# punta arenas cl
# lebu cl
# jamestown sh
# makakilo city us
# port macquarie au
# qaanaaq gl
# rikitea pf
# konakovo ru
# taolanaro mg
# fort nelson ca
# ushuaia ar
# digha in
# watrous ca
# chaykovskaya ru
# mehamn no
# kodiak us
# kodiak us
# khor qa
# hithadhoo mv
# souillac mu
# kalush ua
# kholodnyy ru
# barrow us
# glace bay ca
# pandamatenga bw
# puerto ayora ec
# bathsheba bb
# san vicente cl
# aguai br
# grand river south east mu
# mys shmidta ru
# busselton au
# thompson ca
# butwal np
# vagay ru
# mataura pf
# alma us
# illoqqortoormiut gl
# vostok ru
# bluff nz
# filiates gr
# terney ru
# avarua ck
# new norfolk au
# ushuaia ar
# lebu cl
# saint-joseph re
# jonava lt
# busselton au
# ushuaia ar
# yulara au
# elizabeth city us
# balezino ru
# gamba ga
# puerto ayora ec
# busselton au
# rikitea pf
# barentsburg sj
# saint-philippe re
# aflu dz
# nguiu au
# wuwei cn
# new norfolk au
# barra patuca hn
# mataura pf
# mitsamiouli km
# ushuaia ar
# lerici it
# mar del plata ar
# punta arenas cl
# sao filipe cv
# askiz ru
# taolanaro mg
# rikitea pf

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# preview city data 
cities[0:10]
# Out:
# ['coihaique',
#  'rikitea',
#  'iqaluit',
#  'kodiak',
#  'mount gambier',
#  'la baule-escoublac',
#  'hermanus',
#  'albany',
#  'kemin',
#  'avarua']

# %% [markdown]
# # Get Weather Data

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

#print(url)

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Toronto"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e402a57f7c0fdfb13409847bed7b5cac&q=Toronto

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Toronto"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-79.4163,"lat":43.7001},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}],"base":"stations","main":{"temp":41.9,"feels_like":33.64,"temp_min":40.35,"temp_max":43.2,"pressure":1004,"humidity":87},"visibility":10000,"wind":{"speed":17.27,"deg":260},"clouds":{"all":100},"dt":1647747624,"sys":{"type":2,"id":2040045,"country":"CA","sunrise":1647688961,"sunset":1647732489},"timezone":-14400,"id":6167865,"name":"Toronto","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -79.4163, 'lat': 43.7001},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 41.9,
#   'feels_like': 33.64,
#   'temp_min': 40.35,
#   'temp_max': 43.2,
#   'pressure': 1004,
#   'humidity': 87},
#  'visibility': 10000,
#  'wind': {'speed': 17.27, 'deg': 260},
#  'clouds': {'all': 100},
#  'dt': 1647747624,
#  'sys': {'type': 2,
#   'id': 2040045,
#   'country': 'CA',
#   'sunrise': 1647688961,
#   'sunset': 1647732489},
#  'timezone': -14400,
#  'id': 6167865,
#  'name': 'Toronto',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Toronto"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City weather not found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Toronto"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -79.4163, 'lat': 43.7001},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 41.9,
#   'feels_like': 33.64,
#   'temp_min': 40.35,
#   'temp_max': 43.2,
#   'pressure': 1004,
#   'humidity': 87},
#  'visibility': 10000,
#  'wind': {'speed': 17.27, 'deg': 260},
#  'clouds': {'all': 100},
#  'dt': 1647747624,
#  'sys': {'type': 2,
#   'id': 2040045,
#   'country': 'CA',
#   'sunrise': 1647688961,
#   'sunset': 1647732489},
#  'timezone': -14400,
#  'id': 6167865,
#  'name': 'Toronto',
#  'cod': 200}

# %%
# Get the JSON data.
Toronto_data = city_weather.json()

# %%
Toronto_data['weather'][0]['description']
# Out:
# 'overcast clouds'

# %%
#a = {'Age':23,'Biodata':{'Name':'Abhiram','School':'Syracuse'}}
#a['Biodata']['Name']

# %%
Toronto_data['sys']
# Out:
# {'type': 2,
#  'id': 2040045,
#  'country': 'CA',
#  'sunrise': 1647688961,
#  'sunset': 1647732489}

# %%
# country data
Toronto_data['sys'] ["country"]
# Out:
# 'CA'

# %%
#latitude value from the Boston JSON data
Toronto_data["coord"]["lat"]
# Out:
# 43.7001

# %%
#maximum temperature value from the Boston JSON data
Toronto_data["main"]["temp_max"]
# Out:
# 43.2

# %%
#latitude, longitude, maximum temperature, humidity, percent cloudiness, and wind speed. 
lat = Toronto_data["coord"]["lat"]
lng = Toronto_data["coord"]["lon"]
max_temp = Toronto_data["main"]["temp_max"]
humidity = Toronto_data["main"]["humidity"]
clouds = Toronto_data["clouds"]["all"]
wind = Toronto_data["wind"]["speed"]
description = Toronto_data['weather'][0]['description']
print(lat, lng, max_temp, humidity, clouds, wind, description)
# Out:
# 43.7001 -79.4163 43.2 87 100 17.27 overcast clouds

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = Toronto_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2022-03-20 03:40:24'

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

    # Loop through all the cities in the list.
for i, city in enumerate(cities): #enumerate(cities[:30]): to enumerate 10 cities as a test, needs to be removed for the 610 cities

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(1)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities. Ctrl + ]
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather["weather"][0]["description"]

        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                        "Lat": city_lat,
                        "Lng": city_lng,
                        "Max Temp": city_max_temp,
                        "Humidity": city_humidity,
                        "Cloudiness": city_clouds,
                        "Wind Speed": city_wind,
                        "Country": city_country,
                        "Current Description": description})

    # If an error is experienced, skip the city.
    except:
            print("City not found. Skipping...")
            pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | coihaique
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | iqaluit
# Processing Record 4 of Set 1 | kodiak
# Processing Record 5 of Set 1 | mount gambier
# Processing Record 6 of Set 1 | la baule-escoublac
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | kemin
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | sawtell
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | kahului
# Processing Record 14 of Set 1 | saldanha
# Processing Record 15 of Set 1 | general roca
# Processing Record 16 of Set 1 | ponta do sol
# Processing Record 17 of Set 1 | cidreira
# Processing Record 18 of Set 1 | batagay-alyta
# Processing Record 19 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | tuatapere
# Processing Record 22 of Set 1 | ulaanbaatar
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | houma
# Processing Record 26 of Set 1 | sao filipe
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | uwayl
# City not found. Skipping...
# Processing Record 29 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | san patricio
# Processing Record 33 of Set 1 | buala
# Processing Record 34 of Set 1 | hami
# Processing Record 35 of Set 1 | longyearbyen
# Processing Record 36 of Set 1 | dubbo
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | hithadhoo
# Processing Record 40 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 1 | santa luzia
# Processing Record 42 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 1 | saskylakh
# Processing Record 44 of Set 1 | fairborn
# Processing Record 45 of Set 1 | severo-kurilsk
# Processing Record 46 of Set 1 | faanui
# Processing Record 47 of Set 1 | egvekinot
# Processing Record 48 of Set 1 | kudahuvadhoo
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | erzin
# Processing Record 1 of Set 2 | torbay
# Processing Record 2 of Set 2 | stoyba
# City not found. Skipping...
# Processing Record 3 of Set 2 | grand gaube
# Processing Record 4 of Set 2 | shetpe
# Processing Record 5 of Set 2 | muros
# Processing Record 6 of Set 2 | dikson
# Processing Record 7 of Set 2 | melfi
# Processing Record 8 of Set 2 | talnakh
# Processing Record 9 of Set 2 | butaritari
# Processing Record 10 of Set 2 | manggar
# Processing Record 11 of Set 2 | provideniya
# Processing Record 12 of Set 2 | yanji
# Processing Record 13 of Set 2 | georgetown
# Processing Record 14 of Set 2 | san rafael del sur
# Processing Record 15 of Set 2 | khatanga
# Processing Record 16 of Set 2 | sitka
# Processing Record 17 of Set 2 | goderich
# Processing Record 18 of Set 2 | fortuna
# Processing Record 19 of Set 2 | atuona
# Processing Record 20 of Set 2 | vardo
# Processing Record 21 of Set 2 | marawi
# Processing Record 22 of Set 2 | codrington
# Processing Record 23 of Set 2 | dossor
# Processing Record 24 of Set 2 | karratha
# Processing Record 25 of Set 2 | caravelas
# Processing Record 26 of Set 2 | camana
# Processing Record 27 of Set 2 | bethel
# Processing Record 28 of Set 2 | tamandare
# Processing Record 29 of Set 2 | yertsevo
# Processing Record 30 of Set 2 | coolum beach
# Processing Record 31 of Set 2 | kismayo
# Processing Record 32 of Set 2 | dawlatabad
# Processing Record 33 of Set 2 | port keats
# Processing Record 34 of Set 2 | bayan
# Processing Record 35 of Set 2 | katsuura
# Processing Record 36 of Set 2 | leh
# Processing Record 37 of Set 2 | omboue
# Processing Record 38 of Set 2 | roma
# Processing Record 39 of Set 2 | birjand
# Processing Record 40 of Set 2 | norman wells
# Processing Record 41 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 2 | qaanaaq
# Processing Record 43 of Set 2 | dawei
# Processing Record 44 of Set 2 | lebu
# Processing Record 45 of Set 2 | east london
# Processing Record 46 of Set 2 | tasiilaq
# Processing Record 47 of Set 2 | promyshlennyy
# Processing Record 48 of Set 2 | kachiry
# Processing Record 49 of Set 2 | kenai
# Processing Record 50 of Set 2 | port blair
# Processing Record 1 of Set 3 | cape town
# Processing Record 2 of Set 3 | almaznyy
# Processing Record 3 of Set 3 | severnyy
# Processing Record 4 of Set 3 | evensk
# Processing Record 5 of Set 3 | bengkulu
# Processing Record 6 of Set 3 | airai
# Processing Record 7 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 3 | la romana
# Processing Record 9 of Set 3 | paamiut
# Processing Record 10 of Set 3 | port elizabeth
# Processing Record 11 of Set 3 | castro
# Processing Record 12 of Set 3 | nemuro
# Processing Record 13 of Set 3 | the valley
# Processing Record 14 of Set 3 | vaini
# Processing Record 15 of Set 3 | bara
# Processing Record 16 of Set 3 | phangnga
# Processing Record 17 of Set 3 | lakatoro
# Processing Record 18 of Set 3 | chuy
# Processing Record 19 of Set 3 | mahebourg
# Processing Record 20 of Set 3 | chernogorsk
# Processing Record 21 of Set 3 | ribeira grande
# Processing Record 22 of Set 3 | tiksi
# Processing Record 23 of Set 3 | xingyi
# Processing Record 24 of Set 3 | gazli
# Processing Record 25 of Set 3 | saint-philippe
# Processing Record 26 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 3 | pajapan
# Processing Record 28 of Set 3 | bredasdorp
# Processing Record 29 of Set 3 | fuyu
# Processing Record 30 of Set 3 | victoria
# Processing Record 31 of Set 3 | kedougou
# Processing Record 32 of Set 3 | baiyin
# Processing Record 33 of Set 3 | maxixe
# Processing Record 34 of Set 3 | barrow
# Processing Record 35 of Set 3 | carnarvon
# Processing Record 36 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 3 | guerrero negro
# Processing Record 38 of Set 3 | thunder bay
# Processing Record 39 of Set 3 | kaitangata
# Processing Record 40 of Set 3 | tapaua
# City not found. Skipping...
# Processing Record 41 of Set 3 | mar del plata
# Processing Record 42 of Set 3 | broome
# Processing Record 43 of Set 3 | morant bay
# Processing Record 44 of Set 3 | port-gentil
# Processing Record 45 of Set 3 | amethi
# Processing Record 46 of Set 3 | ambon
# Processing Record 47 of Set 3 | havre-saint-pierre
# Processing Record 48 of Set 3 | new norfolk
# Processing Record 49 of Set 3 | bathsheba
# Processing Record 50 of Set 3 | lavrentiya
# Processing Record 1 of Set 4 | husavik
# Processing Record 2 of Set 4 | baicheng
# Processing Record 3 of Set 4 | fort nelson
# Processing Record 4 of Set 4 | lata
# Processing Record 5 of Set 4 | hilo
# Processing Record 6 of Set 4 | gat
# Processing Record 7 of Set 4 | luena
# Processing Record 8 of Set 4 | mozarlandia
# Processing Record 9 of Set 4 | ust-kuyga
# Processing Record 10 of Set 4 | campbell river
# Processing Record 11 of Set 4 | sechura
# Processing Record 12 of Set 4 | saint stephen
# Processing Record 13 of Set 4 | rumoi
# Processing Record 14 of Set 4 | sola
# Processing Record 15 of Set 4 | leningradskiy
# Processing Record 16 of Set 4 | upernavik
# Processing Record 17 of Set 4 | ancud
# Processing Record 18 of Set 4 | kalabo
# Processing Record 19 of Set 4 | pangnirtung
# Processing Record 20 of Set 4 | kruisfontein
# Processing Record 21 of Set 4 | riviere-du-loup
# Processing Record 22 of Set 4 | wuchi
# Processing Record 23 of Set 4 | lagoa
# Processing Record 24 of Set 4 | buraydah
# Processing Record 25 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 26 of Set 4 | umm lajj
# Processing Record 27 of Set 4 | iralaya
# Processing Record 28 of Set 4 | andenes
# Processing Record 29 of Set 4 | bambous virieux
# Processing Record 30 of Set 4 | kathu
# Processing Record 31 of Set 4 | tarabuco
# Processing Record 32 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 4 | laguna
# Processing Record 34 of Set 4 | faya
# Processing Record 35 of Set 4 | nikolskoye
# Processing Record 36 of Set 4 | tuktoyaktuk
# Processing Record 37 of Set 4 | samsun
# Processing Record 38 of Set 4 | klaksvik
# Processing Record 39 of Set 4 | ugoofaaru
# Processing Record 40 of Set 4 | bell ville
# Processing Record 41 of Set 4 | sisimiut
# Processing Record 42 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 4 | coxim
# Processing Record 44 of Set 4 | mangrol
# Processing Record 45 of Set 4 | thompson
# Processing Record 46 of Set 4 | princeton
# Processing Record 47 of Set 4 | breves
# Processing Record 48 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 4 | avera
# Processing Record 50 of Set 4 | consett
# Processing Record 1 of Set 5 | tambura
# Processing Record 2 of Set 5 | bruck an der leitha
# Processing Record 3 of Set 5 | chokurdakh
# Processing Record 4 of Set 5 | solnechnyy
# Processing Record 5 of Set 5 | larsnes
# Processing Record 6 of Set 5 | nabire
# Processing Record 7 of Set 5 | salalah
# Processing Record 8 of Set 5 | sioux lookout
# Processing Record 9 of Set 5 | hofn
# Processing Record 10 of Set 5 | marabba
# Processing Record 11 of Set 5 | sibolga
# Processing Record 12 of Set 5 | kapaa
# Processing Record 13 of Set 5 | lucea
# Processing Record 14 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 15 of Set 5 | clarksburg
# Processing Record 16 of Set 5 | harper
# Processing Record 17 of Set 5 | kabare
# Processing Record 18 of Set 5 | juneau
# Processing Record 19 of Set 5 | saint-leu
# Processing Record 20 of Set 5 | seoul
# Processing Record 21 of Set 5 | oksfjord
# Processing Record 22 of Set 5 | barcelos
# Processing Record 23 of Set 5 | toamasina
# Processing Record 24 of Set 5 | mamallapuram
# Processing Record 25 of Set 5 | aklavik
# Processing Record 26 of Set 5 | olafsvik
# Processing Record 27 of Set 5 | cheuskiny
# City not found. Skipping...
# Processing Record 28 of Set 5 | arraial do cabo
# Processing Record 29 of Set 5 | dicabisagan
# Processing Record 30 of Set 5 | clinton
# Processing Record 31 of Set 5 | cherskiy
# Processing Record 32 of Set 5 | raudeberg
# Processing Record 33 of Set 5 | lokosovo
# Processing Record 34 of Set 5 | dhidhdhoo
# Processing Record 35 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 5 | catuday
# Processing Record 37 of Set 5 | ilulissat
# Processing Record 38 of Set 5 | inirida
# Processing Record 39 of Set 5 | yarim
# Processing Record 40 of Set 5 | cabo san lucas
# Processing Record 41 of Set 5 | san cristobal
# Processing Record 42 of Set 5 | naze
# Processing Record 43 of Set 5 | mangan
# Processing Record 44 of Set 5 | kangaba
# Processing Record 45 of Set 5 | tighnabruaich
# Processing Record 46 of Set 5 | lompoc
# Processing Record 47 of Set 5 | santa lucia
# Processing Record 48 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 49 of Set 5 | bakel
# Processing Record 50 of Set 5 | bandarbeyla
# Processing Record 1 of Set 6 | mhlume
# Processing Record 2 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 3 of Set 6 | port hedland
# Processing Record 4 of Set 6 | vila
# Processing Record 5 of Set 6 | palauig
# Processing Record 6 of Set 6 | berezovka
# Processing Record 7 of Set 6 | chaman
# Processing Record 8 of Set 6 | griffith
# Processing Record 9 of Set 6 | berlevag
# Processing Record 10 of Set 6 | fairbanks
# Processing Record 11 of Set 6 | vila velha
# Processing Record 12 of Set 6 | port hardy
# Processing Record 13 of Set 6 | isangel
# Processing Record 14 of Set 6 | vila franca do campo
# Processing Record 15 of Set 6 | yanchukan
# City not found. Skipping...
# Processing Record 16 of Set 6 | maringa
# Processing Record 17 of Set 6 | hibbing
# Processing Record 18 of Set 6 | noumea
# Processing Record 19 of Set 6 | bud
# Processing Record 20 of Set 6 | east foothills
# Processing Record 21 of Set 6 | wuan
# Processing Record 22 of Set 6 | vostok
# Processing Record 23 of Set 6 | pindushi
# Processing Record 24 of Set 6 | high level
# Processing Record 25 of Set 6 | kundiawa
# Processing Record 26 of Set 6 | ushtobe
# Processing Record 27 of Set 6 | great yarmouth
# Processing Record 28 of Set 6 | ketchikan
# Processing Record 29 of Set 6 | uyskoye
# Processing Record 30 of Set 6 | grande-riviere
# City not found. Skipping...
# Processing Record 31 of Set 6 | chato
# Processing Record 32 of Set 6 | ostrovnoy
# Processing Record 33 of Set 6 | adre
# Processing Record 34 of Set 6 | khromtau
# Processing Record 35 of Set 6 | strezhevoy
# Processing Record 36 of Set 6 | opportunity
# Processing Record 37 of Set 6 | porvoo
# Processing Record 38 of Set 6 | alibag
# Processing Record 39 of Set 6 | keith
# Processing Record 40 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 6 | chinsali
# Processing Record 42 of Set 6 | ucluelet
# Processing Record 43 of Set 6 | constitucion
# Processing Record 44 of Set 6 | nelson bay
# Processing Record 45 of Set 6 | luau
# Processing Record 46 of Set 6 | hamilton
# Processing Record 47 of Set 6 | manaure
# Processing Record 48 of Set 6 | salmas
# Processing Record 49 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 7 | aspindza
# Processing Record 2 of Set 7 | ahipara
# Processing Record 3 of Set 7 | jiazi
# Processing Record 4 of Set 7 | souillac
# Processing Record 5 of Set 7 | vwawa
# Processing Record 6 of Set 7 | hasaki
# Processing Record 7 of Set 7 | san lorenzo
# Processing Record 8 of Set 7 | lang suan
# Processing Record 9 of Set 7 | svetlyy
# Processing Record 10 of Set 7 | lufilufi
# Processing Record 11 of Set 7 | geraldton
# Processing Record 12 of Set 7 | los llanos de aridane
# Processing Record 13 of Set 7 | anadyr
# Processing Record 14 of Set 7 | spirit river
# Processing Record 15 of Set 7 | zhigansk
# Processing Record 16 of Set 7 | doha
# Processing Record 17 of Set 7 | saint-augustin
# Processing Record 18 of Set 7 | filadelfia
# Processing Record 19 of Set 7 | okha
# Processing Record 20 of Set 7 | beira
# Processing Record 21 of Set 7 | bossembele
# City not found. Skipping...
# Processing Record 22 of Set 7 | gloversville
# Processing Record 23 of Set 7 | narsaq
# Processing Record 24 of Set 7 | oranjestad
# Processing Record 25 of Set 7 | lorengau
# Processing Record 26 of Set 7 | aripuana
# Processing Record 27 of Set 7 | wenling
# Processing Record 28 of Set 7 | monterey
# Processing Record 29 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 7 | maraa
# Processing Record 31 of Set 7 | abnub
# Processing Record 32 of Set 7 | gimli
# Processing Record 33 of Set 7 | ternate
# Processing Record 34 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 35 of Set 7 | puerto escondido
# Processing Record 36 of Set 7 | pyapon
# Processing Record 37 of Set 7 | portoferraio
# Processing Record 38 of Set 7 | chingirlau
# Processing Record 39 of Set 7 | padang
# Processing Record 40 of Set 7 | poum
# Processing Record 41 of Set 7 | knyaze-volkonskoye
# Processing Record 42 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 43 of Set 7 | sawakin
# Processing Record 44 of Set 7 | bonthe
# Processing Record 45 of Set 7 | laje
# Processing Record 46 of Set 7 | bam
# Processing Record 47 of Set 7 | namatanai
# Processing Record 48 of Set 7 | ouro preto do oeste
# Processing Record 49 of Set 7 | clyde river
# Processing Record 50 of Set 7 | limbe
# Processing Record 1 of Set 8 | esperance
# Processing Record 2 of Set 8 | dingle
# Processing Record 3 of Set 8 | along
# Processing Record 4 of Set 8 | romhany
# Processing Record 5 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 6 of Set 8 | gao
# Processing Record 7 of Set 8 | davydivka
# Processing Record 8 of Set 8 | acarau
# Processing Record 9 of Set 8 | nanortalik
# Processing Record 10 of Set 8 | manicore
# Processing Record 11 of Set 8 | college
# Processing Record 12 of Set 8 | pevek
# Processing Record 13 of Set 8 | gazanjyk
# Processing Record 14 of Set 8 | rokupr
# Processing Record 15 of Set 8 | yoichi
# Processing Record 16 of Set 8 | ilhabela
# Processing Record 17 of Set 8 | aitape
# Processing Record 18 of Set 8 | sorong
# Processing Record 19 of Set 8 | krasnoarmeysk
# Processing Record 20 of Set 8 | tenosique
# Processing Record 21 of Set 8 | savannah bight
# Processing Record 22 of Set 8 | dzilam gonzalez
# Processing Record 23 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 24 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 8 | tiarei
# Processing Record 26 of Set 8 | northport
# Processing Record 27 of Set 8 | esil
# Processing Record 28 of Set 8 | lumsden
# Processing Record 29 of Set 8 | ninghai
# Processing Record 30 of Set 8 | komsomolsk-na-amure
# Processing Record 31 of Set 8 | havoysund
# Processing Record 32 of Set 8 | kungurtug
# Processing Record 33 of Set 8 | heilbron
# Processing Record 34 of Set 8 | raffadali
# Processing Record 35 of Set 8 | maldaeni
# Processing Record 36 of Set 8 | matara
# Processing Record 37 of Set 8 | shahr-e kord
# Processing Record 38 of Set 8 | byron bay
# Processing Record 39 of Set 8 | kulevcha
# Processing Record 40 of Set 8 | pisco
# Processing Record 41 of Set 8 | iskateley
# Processing Record 42 of Set 8 | loandjili
# Processing Record 43 of Set 8 | san rafael
# Processing Record 44 of Set 8 | progreso
# Processing Record 45 of Set 8 | bocaranga
# City not found. Skipping...
# Processing Record 46 of Set 8 | vaitape
# Processing Record 47 of Set 8 | snasa
# Processing Record 48 of Set 8 | luanda
# Processing Record 49 of Set 8 | emerald
# Processing Record 50 of Set 8 | januaria
# Processing Record 1 of Set 9 | kapoeta
# Processing Record 2 of Set 9 | mirnyy
# Processing Record 3 of Set 9 | bhabua
# Processing Record 4 of Set 9 | haines junction
# Processing Record 5 of Set 9 | meulaboh
# Processing Record 6 of Set 9 | misratah
# Processing Record 7 of Set 9 | pudem
# Processing Record 8 of Set 9 | edd
# Processing Record 9 of Set 9 | erenhot
# Processing Record 10 of Set 9 | san andres
# Processing Record 11 of Set 9 | saint george
# Processing Record 12 of Set 9 | nipawin
# Processing Record 13 of Set 9 | babu
# Processing Record 14 of Set 9 | mansfield
# Processing Record 15 of Set 9 | conceicao do araguaia
# Processing Record 16 of Set 9 | la union
# Processing Record 17 of Set 9 | iglesias
# Processing Record 18 of Set 9 | beloha
# Processing Record 19 of Set 9 | vilanova del cami
# Processing Record 20 of Set 9 | victor harbor
# Processing Record 21 of Set 9 | bako
# Processing Record 22 of Set 9 | severodvinsk
# Processing Record 23 of Set 9 | vanavara
# Processing Record 24 of Set 9 | karakendzha
# City not found. Skipping...
# Processing Record 25 of Set 9 | hualmay
# Processing Record 26 of Set 9 | roebourne
# Processing Record 27 of Set 9 | kamogawa
# Processing Record 28 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 9 | warwick
# Processing Record 30 of Set 9 | turukhansk
# Processing Record 31 of Set 9 | ler
# Processing Record 32 of Set 9 | carauari
# Processing Record 33 of Set 9 | port macquarie
# Processing Record 34 of Set 9 | henties bay
# Processing Record 35 of Set 9 | margate
# Processing Record 36 of Set 9 | coquimbo
# Processing Record 37 of Set 9 | mizdah
# Processing Record 38 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 39 of Set 9 | la ronge
# Processing Record 40 of Set 9 | xining
# Processing Record 41 of Set 9 | tuy hoa
# Processing Record 42 of Set 9 | nanchang
# Processing Record 43 of Set 9 | tashara
# Processing Record 44 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 9 | swan hill
# Processing Record 46 of Set 9 | minuri
# Processing Record 47 of Set 9 | springbok
# Processing Record 48 of Set 9 | caluquembe
# Processing Record 49 of Set 9 | bonavista
# Processing Record 50 of Set 9 | lake city
# Processing Record 1 of Set 10 | namibe
# Processing Record 2 of Set 10 | la paz
# Processing Record 3 of Set 10 | axim
# Processing Record 4 of Set 10 | komsomolskiy
# Processing Record 5 of Set 10 | chernyshevskiy
# Processing Record 6 of Set 10 | shu
# Processing Record 7 of Set 10 | necochea
# Processing Record 8 of Set 10 | lusambo
# Processing Record 9 of Set 10 | eyl
# Processing Record 10 of Set 10 | burnie
# Processing Record 11 of Set 10 | san pedro de uraba
# Processing Record 12 of Set 10 | sangar
# Processing Record 13 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 14 of Set 10 | cayenne
# Processing Record 15 of Set 10 | baoro
# Processing Record 16 of Set 10 | atar
# Processing Record 17 of Set 10 | troyes
# Processing Record 18 of Set 10 | sovetskiy
# Processing Record 19 of Set 10 | buritizeiro
# Processing Record 20 of Set 10 | krasnoselkup
# Processing Record 21 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 22 of Set 10 | jumla
# Processing Record 23 of Set 10 | loreto
# Processing Record 24 of Set 10 | altay
# Processing Record 25 of Set 10 | kochki
# Processing Record 26 of Set 10 | taoudenni
# Processing Record 27 of Set 10 | inhambane
# Processing Record 28 of Set 10 | viedma
# Processing Record 29 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 10 | hambantota
# Processing Record 31 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 32 of Set 10 | atambua
# Processing Record 33 of Set 10 | sudova vyshnya
# Processing Record 34 of Set 10 | cantaura
# Processing Record 35 of Set 10 | buchanan
# Processing Record 36 of Set 10 | malandag
# Processing Record 37 of Set 10 | kedrovyy
# Processing Record 38 of Set 10 | narasannapeta
# Processing Record 39 of Set 10 | beyneu
# Processing Record 40 of Set 10 | altamira
# Processing Record 41 of Set 10 | luderitz
# Processing Record 42 of Set 10 | ouidah
# Processing Record 43 of Set 10 | maniitsoq
# Processing Record 44 of Set 10 | sumbe
# Processing Record 45 of Set 10 | sao joao da barra
# Processing Record 46 of Set 10 | wexford
# Processing Record 47 of Set 10 | aran
# Processing Record 48 of Set 10 | dunedin
# Processing Record 49 of Set 10 | kaka
# Processing Record 50 of Set 10 | tiznit
# Processing Record 1 of Set 11 | shahr-e babak
# Processing Record 2 of Set 11 | naryan-mar
# Processing Record 3 of Set 11 | cedar city
# Processing Record 4 of Set 11 | fayaoue
# Processing Record 5 of Set 11 | shimoda
# Processing Record 6 of Set 11 | pekan
# Processing Record 7 of Set 11 | moose factory
# Processing Record 8 of Set 11 | chor
# Processing Record 9 of Set 11 | praia da vitoria
# Processing Record 10 of Set 11 | rosario oeste
# Processing Record 11 of Set 11 | bodden town
# Processing Record 12 of Set 11 | sudak
# Processing Record 13 of Set 11 | kyzyl-suu
# Processing Record 14 of Set 11 | jacksonville beach
# Processing Record 15 of Set 11 | schwyz
# Processing Record 16 of Set 11 | waingapu
# Processing Record 17 of Set 11 | montepuez
# Processing Record 18 of Set 11 | ambilobe
# Processing Record 19 of Set 11 | newberry
# Processing Record 20 of Set 11 | te anau
# Processing Record 21 of Set 11 | padre bernardo
# Processing Record 22 of Set 11 | qandahar
# City not found. Skipping...
# Processing Record 23 of Set 11 | bilma
# Processing Record 24 of Set 11 | goias
# Processing Record 25 of Set 11 | sao sebastiao
# Processing Record 26 of Set 11 | narrabri
# Processing Record 27 of Set 11 | aguimes
# Processing Record 28 of Set 11 | khrustalnyy
# City not found. Skipping...
# Processing Record 29 of Set 11 | edson
# Processing Record 30 of Set 11 | curup
# Processing Record 31 of Set 11 | filotion
# Processing Record 32 of Set 11 | batemans bay
# Processing Record 33 of Set 11 | kununurra
# Processing Record 34 of Set 11 | nhulunbuy
# Processing Record 35 of Set 11 | krasnyy yar
# Processing Record 36 of Set 11 | vinkovci
# Processing Record 37 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 38 of Set 11 | riyadh
# Processing Record 39 of Set 11 | banjar
# Processing Record 40 of Set 11 | broken hill
# Processing Record 41 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 42 of Set 11 | ballina
# Processing Record 43 of Set 11 | santa fe
# Processing Record 44 of Set 11 | shima
# Processing Record 45 of Set 11 | terrace bay
# Processing Record 46 of Set 11 | jiquinlaca
# Processing Record 47 of Set 11 | flin flon
# Processing Record 48 of Set 11 | yurkivka
# Processing Record 49 of Set 11 | tobol
# Processing Record 50 of Set 11 | vao
# Processing Record 1 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 2 of Set 12 | jinchengjiang
# City not found. Skipping...
# Processing Record 3 of Set 12 | merauke
# Processing Record 4 of Set 12 | alegrete
# Processing Record 5 of Set 12 | amahai
# Processing Record 6 of Set 12 | yamada
# Processing Record 7 of Set 12 | ixtapa
# Processing Record 8 of Set 12 | puri
# Processing Record 9 of Set 12 | norrtalje
# Processing Record 10 of Set 12 | zhangjiakou
# Processing Record 11 of Set 12 | abalak
# Processing Record 12 of Set 12 | dudinka
# Processing Record 13 of Set 12 | chumikan
# Processing Record 14 of Set 12 | zhoucheng
# Processing Record 15 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 12 | lebane
# Processing Record 17 of Set 12 | porosozero
# Processing Record 18 of Set 12 | port moresby
# Processing Record 19 of Set 12 | oyama
# Processing Record 20 of Set 12 | lazaro cardenas
# Processing Record 21 of Set 12 | pandamatenga
# Processing Record 22 of Set 12 | kavaratti
# Processing Record 23 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 24 of Set 12 | ilo
# Processing Record 25 of Set 12 | pangody
# Processing Record 26 of Set 12 | saint-pierre
# Processing Record 27 of Set 12 | cuiluan
# Processing Record 28 of Set 12 | mareeba
# Processing Record 29 of Set 12 | darhan
# Processing Record 30 of Set 12 | deputatskiy
# Processing Record 31 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 12 | marzuq
# Processing Record 33 of Set 12 | bosaso
# Processing Record 34 of Set 12 | tommot
# Processing Record 35 of Set 12 | zaragoza
# Processing Record 36 of Set 12 | puerto carreno
# Processing Record 37 of Set 12 | wajir
# Processing Record 38 of Set 12 | poronaysk
# Processing Record 39 of Set 12 | bairiki
# Processing Record 40 of Set 12 | magrath
# Processing Record 41 of Set 12 | ewa beach
# Processing Record 42 of Set 12 | cuamba
# Processing Record 43 of Set 12 | portsmouth
# Processing Record 44 of Set 12 | rojhan
# Processing Record 45 of Set 12 | verkhnyaya inta
# Processing Record 46 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 47 of Set 12 | safford
# Processing Record 48 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 49 of Set 12 | mackay
# Processing Record 50 of Set 12 | rocha
# Processing Record 1 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 2 of Set 13 | hukuntsi
# Processing Record 3 of Set 13 | la rioja
# Processing Record 4 of Set 13 | kapuskasing
# Processing Record 5 of Set 13 | khani
# Processing Record 6 of Set 13 | ulladulla
# Processing Record 7 of Set 13 | lakes entrance
# Processing Record 8 of Set 13 | gamba
# Processing Record 9 of Set 13 | petrov val
# Processing Record 10 of Set 13 | ola
# Processing Record 11 of Set 13 | siguiri
# Processing Record 12 of Set 13 | male
# Processing Record 13 of Set 13 | lodingen
# Processing Record 14 of Set 13 | liwale
# Processing Record 15 of Set 13 | mossendjo
# Processing Record 16 of Set 13 | alice springs
# Processing Record 17 of Set 13 | kavieng
# Processing Record 18 of Set 13 | boma
# Processing Record 19 of Set 13 | mayo
# Processing Record 20 of Set 13 | lukulu
# Processing Record 21 of Set 13 | quatre cocos
# Processing Record 22 of Set 13 | kloulklubed
# Processing Record 23 of Set 13 | moerai
# Processing Record 24 of Set 13 | tazmalt
# Processing Record 25 of Set 13 | impruneta
# Processing Record 26 of Set 13 | tessalit
# Processing Record 27 of Set 13 | tucumcari
# Processing Record 28 of Set 13 | dolinsk
# Processing Record 29 of Set 13 | cabra
# Processing Record 30 of Set 13 | sitrah
# Processing Record 31 of Set 13 | chicama
# Processing Record 32 of Set 13 | vestmannaeyjar
# Processing Record 33 of Set 13 | juntas
# Processing Record 34 of Set 13 | barcelona
# Processing Record 35 of Set 13 | sahrak
# City not found. Skipping...
# Processing Record 36 of Set 13 | santa rosa
# Processing Record 37 of Set 13 | matadi
# Processing Record 38 of Set 13 | ochakiv
# Processing Record 39 of Set 13 | duki
# Processing Record 40 of Set 13 | daru
# Processing Record 41 of Set 13 | san onofre
# Processing Record 42 of Set 13 | camacha
# Processing Record 43 of Set 13 | grindavik
# Processing Record 44 of Set 13 | port augusta
# Processing Record 45 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 13 | hay river
# Processing Record 47 of Set 13 | koppal
# Processing Record 48 of Set 13 | mto wa mbu
# Processing Record 49 of Set 13 | baijiantan
# Processing Record 50 of Set 13 | calama
# Processing Record 1 of Set 14 | trincomalee
# Processing Record 2 of Set 14 | polewali
# Processing Record 3 of Set 14 | jalu
# Processing Record 4 of Set 14 | kropotkin
# Processing Record 5 of Set 14 | belmonte
# Processing Record 6 of Set 14 | otjimbingwe
# Processing Record 7 of Set 14 | chapais
# Processing Record 8 of Set 14 | shadrinsk
# Processing Record 9 of Set 14 | escarcega
# Processing Record 10 of Set 14 | saint-francois
# Processing Record 11 of Set 14 | biltine
# Processing Record 12 of Set 14 | mikuni
# Processing Record 13 of Set 14 | norton
# Processing Record 14 of Set 14 | sovkhoznyy
# Processing Record 15 of Set 14 | nokaneng
# Processing Record 16 of Set 14 | urengoy
# Processing Record 17 of Set 14 | okato
# Processing Record 18 of Set 14 | connersville
# Processing Record 19 of Set 14 | palmer
# Processing Record 20 of Set 14 | shakhovskaya
# Processing Record 21 of Set 14 | gulshat
# City not found. Skipping...
# Processing Record 22 of Set 14 | lugovoy
# Processing Record 23 of Set 14 | pouembout
# Processing Record 24 of Set 14 | chai badan
# Processing Record 25 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 14 | caxito
# Processing Record 27 of Set 14 | rio grande
# Processing Record 28 of Set 14 | adrar
# Processing Record 29 of Set 14 | moron
# Processing Record 30 of Set 14 | nisia floresta
# Processing Record 31 of Set 14 | mangai
# Processing Record 32 of Set 14 | bom jesus
# Processing Record 33 of Set 14 | makakilo city
# Processing Record 34 of Set 14 | aden
# Processing Record 35 of Set 14 | praia
# Processing Record 36 of Set 14 | suluq
# Processing Record 37 of Set 14 | manzhouli
# Processing Record 38 of Set 14 | mount isa
# Processing Record 39 of Set 14 | saint peter
# Processing Record 40 of Set 14 | chateauroux
# Processing Record 41 of Set 14 | colares
# Processing Record 42 of Set 14 | praya
# Processing Record 43 of Set 14 | kilmez
# City not found. Skipping...
# Processing Record 44 of Set 14 | dukat
# Processing Record 45 of Set 14 | vila real
# Processing Record 46 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 47 of Set 14 | asahikawa
# Processing Record 48 of Set 14 | senanga
# Processing Record 49 of Set 14 | bauru
# Processing Record 50 of Set 14 | rivers
# Processing Record 1 of Set 15 | yumen
# Processing Record 2 of Set 15 | tunghsiao
# City not found. Skipping...
# Processing Record 3 of Set 15 | slave lake
# Processing Record 4 of Set 15 | saint-chamond
# Processing Record 5 of Set 15 | mugur-aksy
# Processing Record 6 of Set 15 | hovd
# Processing Record 7 of Set 15 | old road
# City not found. Skipping...
# Processing Record 8 of Set 15 | mayskiy
# Processing Record 9 of Set 15 | am timan
# Processing Record 10 of Set 15 | half moon bay
# Processing Record 11 of Set 15 | oranjemund
# Processing Record 12 of Set 15 | aswan
# Processing Record 13 of Set 15 | novikovo
# Processing Record 14 of Set 15 | beisfjord
# Processing Record 15 of Set 15 | quelimane
# Processing Record 16 of Set 15 | halol
# Processing Record 17 of Set 15 | lisakovsk
# Processing Record 18 of Set 15 | sept-iles
# Processing Record 19 of Set 15 | palmas
# Processing Record 20 of Set 15 | mackenzie
# Processing Record 21 of Set 15 | ponta delgada
# Processing Record 22 of Set 15 | borger
# Processing Record 23 of Set 15 | eureka
# Processing Record 24 of Set 15 | kamenka
# Processing Record 25 of Set 15 | tahta
# Processing Record 26 of Set 15 | asau
# Processing Record 27 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 28 of Set 15 | rondonopolis
# Processing Record 29 of Set 15 | samokov
# Processing Record 30 of Set 15 | karmana
# City not found. Skipping...
# Processing Record 31 of Set 15 | la peca
# Processing Record 32 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 33 of Set 15 | notodden
# Processing Record 34 of Set 15 | namalenga
# Processing Record 35 of Set 15 | hirara
# Processing Record 36 of Set 15 | durban
# Processing Record 37 of Set 15 | abu kamal
# Processing Record 38 of Set 15 | alofi
# Processing Record 39 of Set 15 | yulara
# Processing Record 40 of Set 15 | konakovo
# Processing Record 41 of Set 15 | digha
# Processing Record 42 of Set 15 | watrous
# Processing Record 43 of Set 15 | chaykovskaya
# Processing Record 44 of Set 15 | mehamn
# Processing Record 45 of Set 15 | khor
# Processing Record 46 of Set 15 | kalush
# Processing Record 47 of Set 15 | kholodnyy
# Processing Record 48 of Set 15 | glace bay
# Processing Record 49 of Set 15 | san vicente
# Processing Record 50 of Set 15 | aguai
# Processing Record 1 of Set 16 | butwal
# Processing Record 2 of Set 16 | vagay
# Processing Record 3 of Set 16 | alma
# Processing Record 4 of Set 16 | filiates
# Processing Record 5 of Set 16 | terney
# Processing Record 6 of Set 16 | saint-joseph
# Processing Record 7 of Set 16 | jonava
# Processing Record 8 of Set 16 | elizabeth city
# Processing Record 9 of Set 16 | balezino
# Processing Record 10 of Set 16 | aflu
# City not found. Skipping...
# Processing Record 11 of Set 16 | nguiu
# City not found. Skipping...
# Processing Record 12 of Set 16 | wuwei
# Processing Record 13 of Set 16 | barra patuca
# Processing Record 14 of Set 16 | mitsamiouli
# Processing Record 15 of Set 16 | lerici
# Processing Record 16 of Set 16 | askiz
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(city_data[0:3])
# Out:
# [{'City': 'Coihaique', 'Lat': -45.5752, 'Lng': -72.0662, 'Max Temp': 54.21, 'Humidity': 76, 'Cloudiness': 100, 'Wind Speed': 1.14, 'Country': 'CL', 'Current Description': 'overcast clouds'}, {'City': 'Rikitea', 'Lat': -23.1203, 'Lng': -134.9692, 'Max Temp': 80.64, 'Humidity': 74, 'Cloudiness': 26, 'Wind Speed': 10.22, 'Country': 'PF', 'Current Description': 'light rain'}, {'City': 'Iqaluit', 'Lat': 63.7506, 'Lng': -68.5145, 'Max Temp': -20.31, 'Humidity': 75, 'Cloudiness': 0, 'Wind Speed': 2.3, 'Country': 'CA', 'Current Description': 'clear sky'}]

# %%
len(city_data)
# Out:
# 701

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Coihaique -45.5752  -72.0662     54.21        76         100
# 1             Rikitea -23.1203 -134.9692     80.64        74          26
# 2             Iqaluit  63.7506  -68.5145    -20.31        75           0
# 3              Kodiak  57.7900 -152.4072     36.91        81         100
# 4       Mount Gambier -37.8333  140.7667     69.71        60         100
# 5  La Baule-Escoublac  47.2922   -2.3640     48.70        85          99
# 6            Hermanus -34.4187   19.2345     70.81        89          31
# 7              Albany  42.6001  -73.9662     53.22        92          61
# 8               Kemin  42.7846   75.6892     31.51        91         100
# 9              Avarua -21.2078 -159.7750     82.45        74          49
#
#    Wind Speed Country Current Description
# 0        1.14      CL     overcast clouds
# 1       10.22      PF          light rain
# 2        2.30      CA           clear sky
# 3       10.36      US          light rain
# 4       13.80      AU     overcast clouds
# 5        5.75      FR     overcast clouds
# 6        9.51      ZA    scattered clouds
# 7        7.05      US       broken clouds
# 8        2.86      KG          light snow
# 9        2.30      CK    scattered clouds

# %%
#rearranging order of the DataFrame
new_column_order = ["City", "Country","Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
# assign a new or the same DataFrame with new column order:
city_data=city_data_df[new_column_order]

# %%
city_data
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Coihaique      CL -45.5752  -72.0662     54.21        76         100
# 1          Rikitea      PF -23.1203 -134.9692     80.64        74          26
# 2          Iqaluit      CA  63.7506  -68.5145    -20.31        75           0
# 3           Kodiak      US  57.7900 -152.4072     36.91        81         100
# 4    Mount Gambier      AU -37.8333  140.7667     69.71        60         100
# ..             ...     ...      ...       ...       ...       ...         ...
# 696          Wuwei      CN  37.9281  102.6414     44.51        28         100
# 697   Barra Patuca      HN  15.8000  -84.2833     78.76        79         100
# 698    Mitsamiouli      KM -11.3847   43.2844     80.89        83          40
# 699         Lerici      IT  44.0759    9.9112     47.86        55           2
# 700          Askiz      RU  53.1319   90.5264     24.62        50          17
#
#      Wind Speed Current Description
# 0          1.14     overcast clouds
# 1         10.22          light rain
# 2          2.30           clear sky
# 3         10.36          light rain
# 4         13.80     overcast clouds
# ..          ...                 ...
# 696        5.39     overcast clouds
# 697       10.54     overcast clouds
# 698        4.61          light rain
# 699        8.16           clear sky
# 700       12.15          few clouds
#
# [701 rows x 9 columns]

# %% [markdown]
# ## Creating a CSV file from output data file

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data.to_csv(output_data_file,index_label="City_ID")

# %% [markdown]
# # Get Data for Plotting

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today
# Out:
# 1647748246.505764

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
from scipy.stats import linregress

# %%
# Import linregress


# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()
    #run this code there will be no output until we call the function with five parameters.

# %% [markdown]
# #### The loc method accesses a group of rows and columns in the current DataFrame by an index, labels, or a Boolean array. The syntax to get a specific row from a current DataFrame is row = df.loc[row_index].

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                           Saldanha
# Lat                            -33.0117
# Lng                             17.9442
# Max Temp                          66.25
# Humidity                             86
# Cloudiness                           32
# Wind Speed                         8.43
# Country                              ZA
# Current Description    scattered clouds
# Name: 13, dtype: object

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)]
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 2               Iqaluit  63.7506  -68.5145    -20.31        75           0
# 3                Kodiak  57.7900 -152.4072     36.91        81         100
# 5    La Baule-Escoublac  47.2922   -2.3640     48.70        85          99
# 7                Albany  42.6001  -73.9662     53.22        92          61
# 8                 Kemin  42.7846   75.6892     31.51        91         100
# ..                  ...      ...       ...       ...       ...         ...
# 695            Balezino  57.9796   53.0106     29.84        94         100
# 696               Wuwei  37.9281  102.6414     44.51        28         100
# 697        Barra Patuca  15.8000  -84.2833     78.76        79         100
# 699              Lerici  44.0759    9.9112     47.86        55           2
# 700               Askiz  53.1319   90.5264     24.62        50          17
#
#      Wind Speed Country Current Description
# 2          2.30      CA           clear sky
# 3         10.36      US          light rain
# 5          5.75      FR     overcast clouds
# 7          7.05      US       broken clouds
# 8          2.86      KG          light snow
# ..          ...     ...                 ...
# 695       11.10      RU          light snow
# 696        5.39      CN     overcast clouds
# 697       10.54      HN     overcast clouds
# 699        8.16      IT           clear sky
# 700       12.15      RU          few clouds
#
# [483 rows x 9 columns]

# %%
# Create Northern and Southern Hemisphere DataFrames. row = df.loc[row_index] . index13 = city_data_df.loc[13]
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', "Max Temp",(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))

# %%
import requests
url = "https://api.spacexdata.com/v2/launchpads"

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))
